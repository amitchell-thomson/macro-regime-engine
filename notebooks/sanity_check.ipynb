# %%
import os
url: str = str(os.getenv("DATABASE_URL"))
print("DATABASE_URL:", url)

from sqlalchemy import create_engine, text
engine = create_engine(url, pool_pre_ping=True)

with engine.connect() as conn:
    print("connected:", conn.execute(text("select version()")).scalar())
# Out:
# DATABASE_URL: postgresql+psycopg2://macro_user:AlecL0vesPostgresql@localhost:5432/macro
# connected: PostgreSQL 16.11 (Homebrew) on aarch64-apple-darwin23.6.0, compiled by Apple clang version 16.0.0 (clang-1600.0.26.6), 64-bit
